# %% [markdown]
# # Testing, Debugigng, Exceptions, Assertions

# %% [markdown]
# Test to debug.
# Defensive programming
#
# Defensive programming attitude
# Document each block, make it modular
#
# First write it as modular as possible. Then make sure it rusts.
#
# 1) Unit testing: validate each piece of program, test each function
#
# 2) regression testing
# add test for bugs as you find them
# catch reintroduced errors that were previously fixed
#
# 3) Integration testing
# does overall program work?
# people tend to rush to do this
#
# How to test.
# 1) test partitions
# 2) random testing
# 3) black box testing
# explore paths through specification
#
# without looking at code. built test cases in different natural space partitions.
# Consider boundary conditions
# 4) glass box testing
# use code to guide test cases
#
# can try and go through every path
#
# guidelines
# branches - exercise all parts of conditionial
# for loop: loop not entered, executed once, executed more than once
# while loop: same, but cases that catch all ways to exit loop. (e.g. break, or while condiiton becomes false)
#
# don't forget boundary cond!
#
# ## Debugging
# can use print statements, e.g. checking correct values are being passed through code, putting them in function, etc.
#
# Use bisection method with print to narrow down where bug is
#
# don't ask what is wrong - ask HOW did I get unexpected result?
#
# different error message in python interpreter.
#
# ### Logic errors
# rubber ducky debugging - explain ur code to someone who barely knows anything
#
# DON'T:
# write entire program
# test entire program
# Debug entire funciton
#
# DO:
# write function, test function, debug function. Make sure to backup code
#
#
# change code, write down potential bug in a comment, Test code, compare new version with old version
#
# ## Exceptions
# error due to unexpected condition. e.g. SyntaxError, NameError, etc.
# Python has HANDLERS for exceptions. Use try block.
# try:
#     a = int(input())
#     b = int(input())
#     print(a/b)
# except:
#     print("Bug")
#
# will print what you want after an exception.
#
# can do specific errors:
# try:
#     a = int(input())
#     b = int(input())
#     print(a/b)
# except ValueError:
#     print("Bug")
# except ZeroDivisionError:
#     print('')
# except:
#     print()
#
# other excptions:
# else block: executed when execution of associated try body completes with no exceptions
# finally:
# - always executed after try, else, except, even if raised another error or executed a break, continue, or return
# -useful for CLEAN-UP code to be run no matter what else happened.
#
# ### What to do about Exceptions
# fail silently (not good)
# error value (still not great). complicates code (have to check for special value)
# stop and give error condition. Raise own exception.
#
# raise Exception("description")
# raise exceptionName(argument)
#
# except statement can return None type. or can specity a return in the except statement, to still output
#
# ## Assertions
# defensive programming at beginning or end
# assert statement
# assert not len(grades) == 0, 'no grades data'
# raises AssertionError ig len(grades) = 0
# otherwise runs ok
#
# as soon as assert violated, program stops. This is convenient because stops progapation and makes it more obvious where the error is
# - check types of arguments or values
# -check data invariants
# -check constraints on return values
# -check for violations of constraing on procedure (e.g. no duplicates in a list)

# %%
########################################
### EXAMPLE: Buggy code to reverse a list
### Try to debug it! (fixes needed are explained below)
########################################
##def rev_list_buggy(L):
##    """
##    input: L, a list
##    Modifies L such that its elements are in reverse order
##    returns: nothing
##    """
##    for i in range(len(L)):
##        j = len(L) - i
##        L[i] = temp
##        L[i] = L[j]
##        L[j] = L[i]
#
## FIXES: --------------------------
## temp unknown
## list index out of range -> sub 1 to j
## get same list back -> iterate only over half
## --------------------------
def rev_list(L):
    """
    input: L, a list
    Modifies L such that its elements are in reverse order
    returns: nothing
    """
    for i in range(len(L)//2):
        j = len(L) - i - 1
        temp = L[i]
        L[i] = L[j]
        L[j] = temp
        
L = [1,2,3,4]
rev_list(L)
print(L)
#
#
########################################
### EXAMPLE: Buggy code to get a list of primes
### Try to debug it! (fixes needed are explained below)
########################################
##def primes_list_buggy(n):
##    """
##    input: n an integer > 1
##    returns: list of all the primes up to and including n
##    """
##    # initialize primes list
##    if i == 2:
##        primes.append(2)
##    # go through each elem of primes list
##    for i in range(len(primes)):
##        # go through each of 2...n
##        for j in range(len(n)):
##            # check if not divisible by elem of list
##            if i%j != 0:
##                primes.append(i)
#
#
## FIXES: --------------------------
## = invalid syntax, variable i unknown, variable primes unknown
## can't apply 'len' to an int
## division by zero -> iterate through elems not indices
##                  -> iterate from 2 not 0
## forgot to return 
## primes is empty list for n > 2
## n = 3 goes through loop once -> range to n+1 not n
## infinite loop -> append j not i
##               -> list is getting modified as iterating over it!
##               -> switch loops around
## n = 4 adds 4 -> need way to stop going once found a divisible num
##              -> use a flag
## --------------------------
def primes_list(n):
    """
    input: n an integer > 1
    returns: list of all the primes up to and including n
    """
    # initialize primes list
    primes = [2]
    # go through each of 3...n
    for j in range(3,n+1):
        is_div = False
        # go through each elem of primes list
        for p in primes:
            if j%p == 0:
                is_div = True
        if not is_div:
            primes.append(j)
    return primes

print(primes_list(2) )               
print(primes_list(15)  )              


######################################
# EXAMPLE: Exceptions and input
######################################
#a = int(input("Tell me one number: "))
#b = int(input("Tell me another number: "))
#print("a/b = ", a/b)
#print("a+b = ", a+b)

try:
    a = int(input("Tell me one number: "))
    b = int(input("Tell me another number: "))
    print("a/b = ", a/b)
except:
    print("Bug in user input.")


try:
    a = int(input("Tell me one number: "))
    b = int(input("Tell me another number: "))
    print("a/b = ", a/b)
    print("a+b = ", a+b)
except ValueError:
    print("Could not convert to a number.")
except ZeroDivisionError:
    print("Can't divide by zero")
except:
    print("Something went very wrong.")



######################################
# EXAMPLE: Raising your own exceptions
######################################
def get_ratios(L1, L2):
    """ Assumes: L1 and L2 are lists of equal length of numbers
        Returns: a list containing L1[i]/L2[i] """
    ratios = []
    for index in range(len(L1)):
        try:
            ratios.append(L1[index]/L2[index])
        except ZeroDivisionError:
            ratios.append(float('nan')) #nan = Not a Number
        except:
            raise ValueError('get_ratios called with bad arg')
        else:
            print("success")
        finally:
            print("executed no matter what!")
    return ratios
    
print(get_ratios([1, 4], [2, 4]))


#######################################
## EXAMPLE: Exceptions and lists
#######################################
def get_stats(class_list):
	new_stats = []
	for person in class_list:
		new_stats.append([person[0], person[1], avg(person[1])])
	return new_stats 

# avg function: version without an exception
#def avg(grades):
#    return (sum(grades))/len(grades)
    
# avg function: version with an exception
def avg(grades):
    try:
        return sum(grades)/len(grades)
    except ZeroDivisionError:
        print('warning: no grades data')
        return 0.0


# avg function: version with assert
def avg(grades):
    assert len(grades) != 0, 'warning: no grades data'
    return sum(grades)/len(grades)

    
test_grades = [[['peter', 'parker'], [80.0, 70.0, 85.0]], 
              [['bruce', 'wayne'], [100.0, 80.0, 74.0]],
              [['captain', 'america'], [80.0, 70.0, 96.0]],
              [['deadpool'], []]]

print(get_stats(test_grades))
