# %% [markdown]
# <a href="https://colab.research.google.com/github/cmskzhan/a2b2c/blob/master/yahooqueries.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# yahoo query
# https://yahooquery-streamlit.herokuapp.com/

# %%
# !pip install yahooquery

from yahooquery import Ticker
aapl = Ticker('aapl')
abt = Ticker('aapl')

aapl.all_modules
# Out:
# {'aapl': {'assetProfile': {'address1': 'One Apple Park Way',
#    'city': 'Cupertino',
#    'state': 'CA',
#    'zip': '95014',
#    'country': 'United States',
#    'phone': '408 996 1010',
#    'website': 'https://www.apple.com',
#    'industry': 'Consumer Electronics',
#    'sector': 'Technology',
# ...

# %%
abt.financial_data
# Out:
# {'aapl': {'maxAge': 86400,
#   'currentPrice': 162.74,
#   'targetHighPrice': 215.0,
#   'targetLowPrice': 160.0,
#   'targetMeanPrice': 192.96,
#   'targetMedianPrice': 197.0,
#   'recommendationMean': 1.8,
#   'recommendationKey': 'buy',
#   'numberOfAnalystOpinions': 44,
#   'totalCash': 63913000960,
#   'totalCashPerShare': 3.916,
#   'ebitda': 128217997312,
#   'totalDebt': 122797998080,
#   'quickRatio': 0.875,
#   'currentRatio': 1.038,
#   'totalRevenue': 378323009536,
#   'debtToEquity': 170.714,
#   'revenuePerShare': 22.838,
#   'returnOnAssets': 0.19875,
#   'returnOnEquity': 1.45567,
#   'grossProfits': 152836000000,
#   'freeCashflow': 80153247744,
#   'operatingCashflow': 112241000448,
#   'earningsGrowth': 0.25,
#   'revenueGrowth': 0.112,
#   'grossMargins': 0.43019,
#   'ebitdaMargins': 0.33890998,
#   'operatingMargins': 0.309,
#   'profitMargins': 0.26579002,
#   'financialCurrency': 'USD'}}

# %%
aapl.cash_flow()
# Out:
#          asOfDate periodType  BeginningCashPosition  CapitalExpenditure  \
# symbol
# aapl   2018-09-30        12M           2.028900e+10       -1.331300e+10
# aapl   2019-09-30        12M           2.591300e+10       -1.049500e+10
# aapl   2020-09-30        12M           5.022400e+10       -7.309000e+09
# aapl   2021-09-30        12M           3.978900e+10       -1.108500e+10
# aapl   2021-12-31        TTM           3.771900e+10       -1.038800e+10
#
#         CashDividendsPaid  CashFlowFromContinuingFinancingActivities  \
# symbol
# aapl        -1.371200e+10                              -8.787600e+10
# aapl        -1.411900e+10                              -9.097600e+10
# aapl        -1.408100e+10                              -8.682000e+10
# aapl        -1.446700e+10                              -9.335300e+10
# aapl        -1.458600e+10                              -8.926300e+10
#
#         ChangeInAccountPayable  ChangeInCashSupplementalAsReported  \
# symbol
# ...

# %%
import pandas as pd
pd.set_option('display.max_rows', 500)
pd.set_option('display.max_columns', 4)
pd.set_option('display.width', 800)
aapl_cashflow=aapl.cash_flow(frequency='q')
print(aapl_cashflow)
# Out:
#          asOfDate periodType  ...  SaleOfInvestment  StockBasedCompensation
# symbol                        ...
# aapl   2020-12-31         3M  ...      3.452100e+10            2.020000e+09
# aapl   2021-03-31         3M  ...      2.672900e+10            1.981000e+09
# aapl   2021-06-30         3M  ...      2.537500e+10            1.960000e+09
# aapl   2021-09-30         3M  ...      2.024500e+10            1.945000e+09
# aapl   2021-12-31         3M  ...      2.198400e+10            2.265000e+09
# aapl   2021-12-31        TTM  ...      9.433300e+10            8.151000e+09
#
# [6 rows x 28 columns]

# %%
# getting the beta value
print(aapl.key_stats['aapl']['beta'])
# Out:
# 1.187468
